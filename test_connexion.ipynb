# %%
import os
from supabase import create_client
from dotenv import load_dotenv

with open("token/token_supabase.txt", "r") as f:
    key = f.read()

load_dotenv()

url = "https://llrscaqomkhqropusqqb.supabase.co"

supabase = create_client(url, key)

response = supabase.table("apartments").select("*").execute()

# %%
response
# Out:
# APIResponse(data=[{'id': 'ae987d6a-083c-4a6e-a9b3-ff1f6e264bc0', 'name': 'Black Tropicalee Suite', 'address': '12 rue de la france, 75001 Paris', 'owner_id': None, 'capacity': 2, 'description': 'super mignon ', 'created_at': '2025-10-31T12:21:46.720434+00:00', 'updated_at': '2026-04-05T22:12:30.501251+00:00', 'image_url': None, 'price_per_night_weekday': 145, 'price_per_night_weekend': 160, 'linen_items': {'bath_mat': {'label': 'Tapis de bain', 'default_quantity': 2}, 'bath_towel': {'label': 'Serviettes de bain', 'default_quantity': 4}, 'hand_towel': {'label': 'Serviettes de toilette', 'default_quantity': 4}, 'pillowcase': {'label': "Taies d'oreiller", 'default_quantity': 4}, 'duvet_cover': {'label': 'Housses de couette', 'default_quantity': 2}, 'sheet_double': {'label': 'Draps 2 personnes', 'default_quantity': 2}, 'sheet_single': {'label': 'Draps 1 personne', 'default_quantity': 2}, 'kitchen_towel': {'label': 'Torchons', 'default_quantity': 3}}, 'phone_number': None, 'website_url': None, 'airbnb_url': None, 'booking_url': None, 'other_platforms': [], 'instagram_url': None, 'facebook_url': None, 'tiktok_url': None, 'youtube_url': None, 'other_socials': [], 'wifi_name': None, 'wifi_password': None, 'housing_type': 'appartement', 'floor_number': None, 'room_count': None, 'distribution': [], 'rent_price': 900, 'access_type': 'boite_a_cles', 'access_code': None, 'management_type': 'propriete', 'additional_infos': None, 'slug': 'black-tropicalee-suite', 'options_page_enabled': True, 'options_page_title': None, 'options_page_description': None, 'options_page_alert_message': None, 'shop_enabled': True, 'shop_page_title': None, 'shop_page_description': None, 'shop_page_alert_message': None, 'tenant_id': '28cb90ba-446d-41c1-a98f-a6abd56a3df8', 'default_cleaning_duration': 60, 'default_laundry_duration': 60, 'status': 'active', 'default_check_in_time': '16:00:00', 'default_check_out_time': '11:00:00', 'surface_area': None, 'has_elevator': False, 'amenities': [], 'photos': [], 'booking_page_enabled': True, 'faq_enabled': False, 'faq_items': [], 'reviews_enabled': False, 'nearby_places': [], 'show_option_prices': True, 'cleaning_fee': 0, 'multisite_enabled': True, 'tourist_tax_per_night': 0, 'pet_fee': 0, 'platform_commission_percentage': 0, 'cleaning_fee_included': False, 'show_cleaning_fee_when_included': True, 'use_default_socials': True, 'show_socials': True, 'pricing_rules': None, 'house_rules': [], 'cancellation_policy': None}, {'id': 'ade690aa-0d13-4248-82d1-35c35fbc1096', 'name': '3eme studio ', 'address': '12 rue de la chance 91340 mars', 'owner_id': 'c8f65808-6ca4-405d-8cf5-585e0b433b32', 'capacity': 2, 'description': 'je suis un mignon studio ', 'created_at': '2025-11-05T10:25:22.253639+00:00', 'updated_at': '2026-03-21T19:23:49.218646+00:00', 'image_url': None, 'price_per_night_weekday': 40, 'price_per_night_weekend': 100, 'linen_items': {'bath_mat': {'label': 'Tapis de bain', 'default_quantity': 2}, 'bath_towel': {'label': 'Serviettes de bain', 'default_quantity': 4}, 'hand_towel': {'label': 'Serviettes de toilette', 'default_quantity': 4}, 'pillowcase': {'label': "Taies d'oreiller", 'default_quantity': 4}, 'duvet_cover': {'label': 'Housses de couette', 'default_quantity': 2}, 'sheet_double': {'label': 'Draps 2 personnes', 'default_quantity': 2}, 'sheet_single': {'label': 'Draps 1 personne', 'default_quantity': 2}, 'kitchen_towel': {'label': 'Torchons', 'default_quantity': 3}}, 'phone_number': None, 'website_url': None, 'airbnb_url': None, 'booking_url': None, 'other_platforms': [], 'instagram_url': None, 'facebook_url': None, 'tiktok_url': None, 'youtube_url': None, 'other_socials': [], 'wifi_name': None, 'wifi_password': None, 'housing_type': 'appartement', 'floor_number': None, 'room_count': None, 'distribution': [], 'rent_price': None, 'access_type': None, 'access_code': None, 'management_type': None, 'additional_infos': None, 'slug': '3eme-studio', 'options_page_enabled': True, 'options_page_title': None, 'options_page_d ...

# %%
data = [data for data in response.data if data["id"] == 'da00ace5-7e20-4e7a-b69b-8755e69401e4']
data_to_save = ["name", "address", "capacity", "description", "price_per_night_weekday","price_per_night_weekend",
                "wifi_name","wifi_password","housing_type","floor_number","room_count","distribution","access_type",
                "default_check_in_time","default_check_out_time", "amenities","cleaning_fee"]
data = data[0]

# %%
data
# Out:
# {'id': 'da00ace5-7e20-4e7a-b69b-8755e69401e4',
#  'name': 'Black Tropicale Suite',
#  'address': 'Rue Robert Schuman 91200 Athis-Mons',
#  'owner_id': None,
#  'capacity': 2,
#  'description': "Bienvenue à la Black Tropical Suite luxury spa 🌴\n\nEnvie de couper du quotidien le temps d’une nuit, d’un week-end ou plus ? La Black Tropical Suite est faite pour vous. C'est un lieu idéal pour un séjour solo, en couple, entre amis ou pour un déplacement professionnel !\nNichée dans un cocon de tranquillité, la Black Tropical Suite est une invitation à la détente et à la tranquillité.\n\n👥 Capacité : jusqu’à 2 voyageurs\n\n🛁 Un espace détente privé\nLa pièce maîtresse de la suite, une somptueuse baignoire balnéo avec jets massants, bulles, lumière et réchauffement de l’eau, idéale pour se détendre après une longue journée ou simplement profiter du moment. Que ce soit en journée ou à la lueur tamisée du soir, c’est l’endroit idéal pour se poser et décompresser.\n\n🛏️ Un espace confortable et intime\n→ Lit Queen size confortable\n→ Coin repas avec une table à manger 2 places\n→ Placard de rangement pour vos affaires\n→ Linge de lit fourni\n→ Fer à repasser à disposition\n→ 🛜 Wi-Fi haut débit\n→ 🎬 Rétroprojecteur avec accès à Netflix et Prime Video INCLUS pour vos soirées films\n→ 🍿 Snacks à disposition pour les petites faims (en supplément)\n\n🍽️ Cuisine équipée et moderne\nVous trouverez sur place une cuisine entièrement équipée avec :\n→ Plaques de cuisson\n→ Four micro-ondes\n→ Mini-réfrigérateur\n→ Machine à café Nespresso (avec dosettes fournies)\n→ Grille-pain\n→ Vaisselle, couverts, verres, casseroles, poêles, ustensiles…\n→ Condiments : Sel, poivre, huile, sucre...\nParfait pour vous préparer un bon petit dîner ou petit-déjeuner tranquille. 🍝\n\n🚿 Salle de bain fonctionnelle et cosy\n→ Douche à l’italienne avec LED\n→ Sèche-cheveux\n→ Miroir LED\n→ Miroir plein pied\n→ Serviettes propres fournies pour le séjour\n→ Produits de toilette de base (gel douche, shampoing)\n\n🎁 Ce qui est fourni pour votre confort\nÀ votre arrivée, vous trouverez quelques petites attentions pour bien démarrer votre séjour :\n→ ☕️ Capsules de café\n→ 🫖 Thé\n→ 💧 Deux petites bouteilles d’eau\n→ 🍪 Petites douceurs/gâteaux\n→ 🧹 Ménage intégral réalisé après chaque séjour\n\n✨ Extras sur demande\nVous venez pour une occasion spéciale (anniversaire, surprise...) ?\nNous proposons des extras personnalisés sur demande :\n→ Déco romantique\n→ Ballons\n→ Petites surprises sur mesure\n→ Arrivée anticipée et départ tardif\n💌 N'hésitez pas à nous contacter à l’avance pour en discuter !\n\nIci, tout est pensé pour favoriser le calme, la déconnexion et le plaisir de savourer l’instant.\nAccès des voyageurs\n📍 Accès & infos pratiques\n\n→ 🚃 10 min à pied du RER C (accès direct Paris en 25 min)\n→ 🚘 Paris est accessible en 35 min en voiture\n→ ✈️ Aéroport d’Orly à 15 min en voiture ou 25 min en transports en commun\n→ 🚍 2 arrêts de bus à moins de 2 minutes à pied du logement\n→ 🅿️ Places de stationnement gratuites à proximité + stationnement payant disponible\n→ 🛒 Supérettes et restaurations accessibles à pied\n\n🔑 Accès autonome avec boîte à clés pour plus de flexibilité\nArrivée anticipée et départ tardif en option possibles sur demande.\n\n🏢 Appartement au rez-de-chaussée, avec entrée indépendante",
#  'created_at': '2026-01-05T11:52:37.329726+00:00',
#  'updated_at': '2026-04-01T09:32:30.415181+00:00',
#  'image_url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/0.4144194176805759.jpeg',
#  'price_per_night_weekday': 145,
#  'price_per_night_weekend': 160,
#  'linen_items': {'bath_mat': {'label': 'Tapis de bain', 'default_quantity': 2},
#   'bath_towel': {'label': 'Serviettes de bain', 'default_quantity': 4},
#   'hand_towel': {'label': 'Serviettes de toilette', 'default_quantity': 4},
#   'pillowcase': {'label': "Taies d'oreiller", 'default_quantity': 4},
#   'duvet_cover': {'label': 'Housses de couette', 'default_quantity': 2},
#   'sheet_double': {'label': 'Draps 2 personnes', 'default_quantity': 2},
#   'sheet_single': {'label': 'Draps 1 personne', 'default_quantity': 2},
#   'kitchen_towel': {'label': 'Torchons', 'default_quantity': 3}},
#  'phone_number': None,
#  'website_url': None,
#  'airbnb_url': 'https://airbnb.fr/h/blacktropicalsuite',
#  'booking_url': None,
#  'other_platforms': [],
#  'instagram_url': None,
#  'facebook_url': None,
#  'tiktok_url': None,
#  'youtube_url': None,
#  'other_socials': [],
#  'wifi_name': 'WIFI_bts',
#  'wifi_password': 'L0v3.26',
#  'housing_type': 'appartement',
#  'floor_number': 'RDC',
#  'room_count': 2,
#  'distribution': ['Cuisine', 'Salle de bain', 'WC', 'Chambre'],
#  'rent_price': 900,
#  'access_type': 'boite_a_cles',
#  'access_code': '1234',
#  'management_type': 'sous_location',
#  'additional_infos': None,
#  'slug': 'black-tropicale-suite',
#  'options_page_enabled': True,
#  'options_page_title': None,
#  'options_page_description': None,
#  'options_page_alert_message': None,
#  'shop_enabled': False,
#  'shop_page_title': None,
#  'shop_page_description': None,
#  'shop_page_alert_message': None,
#  'tenant_id': '6040e4a8-70d9-41da-9098-c07b6dd35d24',
#  'default_cleaning_duration': 60,
#  'default_laundry_duration': 60,
#  'status': 'active',
#  'default_check_in_time': '16:00:00',
#  'default_check_out_time': '11:00:00',
#  'surface_area': 26,
#  'has_elevator': False,
#  'amenities': ['wifi',
#   'chauffage',
#   'refrigerateur',
#   'cafetiere',
#   'cuisine_equipee',
#   'home_cinema',
#   'douche',
#   'micro_ondes',
#   'jacuzzi_balneo',
#   'menage_inclus',
#   'aspirateur',
#   'fer_repasser',
#   'enceinte_bluetooth',
#   'detecteur_fumee',
#   'serviettes',
#   'checkin_autonome',
#   'linge_lit',
#   'conciergerie',
#   'netflix_streaming',
#   'grille_pain'],
#  'photos': [{'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.35267463221102224.jpeg',
#    'order': 0,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.30429376396498.jpeg',
#    'order': 1,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.5096464854849119.jpeg',
#    'order': 2,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.7512841298199427.jpeg',
#    'order': 3,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.669649113555634.jpeg',
#    'order': 4,
#    'caption': 'Snack bar',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.3980705807297681.jpeg',
#    'order': 5,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.35090739499515355.jpeg',
#    'order': 6,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.5301170936460365.jpeg',
#    'order': 7,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.9054073363813068.jpeg',
#    'order': 8,
#    'caption': '',
#    'is_main': True},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.8847981250235324.jpeg',
#    'order': 9,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.16694634230379835.jpeg',
#    'order': 10,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.7103629791864163.jpeg',
#    'order': 11,
#    'caption': 'Cuisine équipé ',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.07018597923442682.jpeg',
#    'order': 12,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.30323158649329474.jpeg',
#    'order': 13,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.42823531570294093.jpeg',
#    'order': 14,
#    'caption': '',
#    'is_main': False},
#   {'url': 'https://llrscaqomkhqropusqqb.supabase.co/storage/v1/object/public/images/apartments/photos/0.4390840904807265.jpeg',
#    'order': 15,
#    'caption': '',
#    'is_main': False}],
#  'booking_page_enabled': True,
#  'faq_enabled': False,
#  'faq_items': [],
#  'reviews_enabled': False,
#  'nearby_places': [],
#  'show_option_prices': False,
#  'cleaning_fee': 25,
#  'multisite_enabled': False,
#  'tourist_tax_per_night': 0,
#  'pet_fee': 0,
#  'platform_commission_percentage': 0,
#  'cleaning_fee_included': False,
#  'show_cleaning_fee_when_included': True,
#  'use_default_socials': True,
#  'show_socials': True,
#  'pricing_rules': None,
#  'house_rules': [],
#  'cancellation_policy': None}

# %%
import json

# appart_data = {k: data[k] for k in set(wanted_keys) & set(old_dict.keys())}
appart_data = {key: data[key] for key in data_to_save}
with open("data/real_appart_data.json", "w") as f:
    json.dump(appart_data, f, indent=3)
